# %% [markdown]
# ## Hate Speech Recognition

# %% [markdown]
# ** Problem Statement **
#
#   Developing an automated hate speech detection system for online platforms to effectively identify and filter hate speech from user-generated content. The system should accurately differentiate between hate speech, offensive language, and benign content, contributing to a safer and more inclusive online environmen

# %%
# IMporting libraries

from nltk.util import pr
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
# Importing data
data = pd.read_csv('twitter.csv')
data.head(25)
# Out:
#     Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0            0      3            0                   0        3      2
# 1            1      3            0                   3        0      1
# 2            2      3            0                   3        0      1
# 3            3      3            0                   2        1      1
# 4            4      6            0                   6        0      1
# 5            5      3            1                   2        0      1
# 6            6      3            0                   3        0      1
# 7            7      3            0                   3        0      1
# 8            8      3            0                   3        0      1
# 9            9      3            1                   2        0      1
# 10          10      3            0                   3        0      1
# 11          11      3            0                   3        0      1
# 12          12      3            0                   2        1      1
# 13          13      3            0                   3        0      1
# 14          14      3            1                   2        0      1
# 15          15      3            0                   3        0      1
# 16          16      3            0                   3        0      1
# 17          17      3            1                   2        0      1
# 18          18      3            0                   3        0      1
# 19          19      3            0                   3        0      1
# 20          20      3            0                   3        0      1
# 21          21      3            0                   3        0      1
# 22          22      3            0                   3        0      1
# 23          23      3            0                   3        0      1
# 24          24      3            0                   3        0      1
#
#                                                 tweet
# 0   !!! RT @mayasolovely: As a woman you shouldn't...
# 1   !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2   !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3   !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4   !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 5   !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...
# 6   !!!!!!"@__BrighterDays: I can not just sit up ...
# 7   !!!!&#8220;@selfiequeenbri: cause I'm tired of...
# 8   " &amp; you might not get ya bitch back &amp; ...
# 9   " @rhythmixx_ :hobbies include: fighting Maria...
# 10  " Keeks is a bitch she curves everyone " lol I...
# 11                 " Murda Gang bitch its Gang Land "
# 12  " So hoes that smoke are losers ? " yea ... go...
# 13      " bad bitches is the only thing that i like "
# 14                            " bitch get up off me "
# 15                    " bitch nigga miss me with it "
# 16                             " bitch plz whatever "
# 17                          " bitch who do you love "
# 18                 " bitches get cut off everyday B "
# 19                 " black bottle &amp; a bad bitch "
# 20               " broke bitch cant tell me nothing "
# 21                    " cancel that bitch like Nino "
# 22            " cant you see these hoes wont change "
# 23  " fuck no that bitch dont even suck dick " &#1...
# 24  " got ya bitch tip toeing on my hardwood floor...

# %%
# Labellling the data

data['labels'] = data['class'].map({0:"Hate Speech" , 1:"Offensive Language" , 2:"No hate and offensive language"})
print(data.head())
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
#
#                                                tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#
#                            labels
# 0  No hate and offensive language
# 1              Offensive Language
# 2              Offensive Language
# 3              Offensive Language
# 4              Offensive Language

# %%
data = data[['tweet' , 'labels']]
print(data.head())
# Out:
#                                                tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
#
#                            labels
# 0  No hate and offensive language
# 1              Offensive Language
# 2              Offensive Language
# 3              Offensive Language
# 4              Offensive Language

# %% [markdown]
# ## NLP

# %%
import re
import nltk
stemmer = nltk.SnowballStemmer('english')
from nltk.corpus import stopwords
import string
stopword = set(stopwords.words('english'))

# %%
def cleantext(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]' , '' , text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text=" ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]

    text = " ".join(text)
    return text
data["tweet"] = data["tweet"].apply(cleantext)
data.head(50)
# Out:
#                                                 tweet  \
# 0    rt mayasolov woman shouldnt complain clean ho...
# 1    rt  boy dat coldtyga dwn bad cuffin dat hoe  ...
# 2    rt urkindofbrand dawg rt  ever fuck bitch sta...
# 3               rt cganderson vivaba look like tranni
# 4    rt shenikarobert shit hear might true might f...
# 5   tmadisonx shit blow meclaim faith somebodi sti...
# 6   brighterday sit hate anoth bitch  got much shi...
# 7              caus im tire big bitch come us skinni
# 8                    amp might get ya bitch back amp
# 9            rhythmixx hobbi includ fight mariambitch
# 10   keek bitch curv everyon  lol walk conver like...
# 11                        murda gang bitch gang land
# 12                       hoe smoke loser   yea  go ig
# 13                              bad bitch thing like
# 14                                         bitch get
# 15                                  bitch nigga miss
# 16                                  bitch plz whatev
# 17                                        bitch love
# 18                          bitch get cut everyday b
# 19                         black bottl amp bad bitch
# 20                        broke bitch cant tell noth
# 21                            cancel bitch like nino
# 22                           cant see hoe wont chang
# 23   fuck bitch dont even suck dick   kermit video...
# 24             got ya bitch tip toe hardwood floor
# 25                       pussi lip like heaven door
# 26                                           hoe hit
# 27              met pussi ocean dr  gave pussi pill
# 28                   need trippi bitch fuck hennessi
# 29                       spend money want bitch busi
# 30              txt old bitch new bitch pussi wetter
# 31     id say im back old old bitch would get excit
# 32            aint bout murder game pussi nigga shut
# 33                         toe aint done pussi stink
# 34         im done bitter bitch wrap  angri bird app
# 35                                          ya bitch
# 36                               aint noth cut bitch
# 37               jus meet son ya mane ass bitch  shot
# 38                           lame cri hoe tear clown
# 39                    like snoop said  dont love hoe
# 40                momma said pussi cat insid doghous
# 41                       hate hoe favorit   sevenon
# 42   nice girl bad make get naughti bad yello hoe ...
# 43                          pimp pimp hoe  futur voic
# 44                       post pictur pussi get  like
# 45                   pussi power drug   happyhumpday
# 46                       quick piec pussi call drive
# 47      run round like brand new pussi bout get fuck
# 48                  bitch even worst theyll send guy
# 49              hoe like nigga spend money talk bout
#
#                             labels
# 0   No hate and offensive language
# 1               Offensive Language
# 2               Offensive Language
# 3               Offensive Language
# 4               Offensive Language
# 5               Offensive Language
# 6               Offensive Language
# 7               Offensive Language
# 8               Offensive Language
# 9               Offensive Language
# 10              Offensive Language
# 11              Offensive Language
# 12              Offensive Language
# 13              Offensive Language
# 14              Offensive Language
# 15              Offensive Language
# 16              Offensive Language
# 17              Offensive Language
# 18              Offensive Language
# 19              Offensive Language
# 20              Offensive Language
# 21              Offensive Language
# 22              Offensive Language
# 23              Offensive Language
# 24              Offensive Language
# 25              Offensive Language
# 26              Offensive Language
# 27              Offensive Language
# 28              Offensive Language
# 29              Offensive Language
# 30              Offensive Language
# 31              Offensive Language
# 32              Offensive Language
# 33              Offensive Language
# 34              Offensive Language
# 35              Offensive Language
# 36              Offensive Language
# 37              Offensive Language
# 38              Offensive Language
# 39              Offensive Language
# 40  No hate and offensive language
# 41              Offensive Language
# 42              Offensive Language
# 43              Offensive Language
# 44              Offensive Language
# 45              Offensive Language
# 46              Offensive Language
# 47              Offensive Language
# 48              Offensive Language
# 49              Offensive Language

# %%
## Dividing data

x = np.array(data['tweet'])
y = np.array(data['labels'])

# %%
cv =CountVectorizer()
X = cv.fit_transform(x) # Fitting the data in X
X_train,X_test, y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.8759919300605246

# %% [markdown]
# ### We get 87% accuracy

# %%
def hate_recognition():
    import streamlit as st
    st.title("Hate Speech Detection")
    user = st.text_area("Enter your tweet:")
    if len(user)<1:
        st.write(" ")
    else:
        sample = user
        data= cv.transform([sample]).toarray()
        a = clf.predict(data)
        st.title(a)
    hate_recognition()
